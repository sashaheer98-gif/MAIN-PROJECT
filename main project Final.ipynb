# %% [markdown]
# # __Data Analytics Final Project__📌
# <hr style="border:2px solid #003366;">

# %% [markdown]
# <h2 style="color:#005B96; font-size:28px;">
# Project Title:Education Using Python
# </h2>

# %% [markdown]
# ### _Project Abstract_
# #### This project analyzes key factors influencing student academic performance by exploring demographic, behavioral, and learning-related variables. Using Python-based (pandas, matplotlib, seaborn)the study identifies patterns that help predict and improve student outcomes.
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ### _Project Description_
#
# #### This project explores how different academic, personal, and environmental factors influence student performance.Using Python, the dataset is cleaned, processed, and analyzed to uncover meaningful trends and correlations.Visualizations and statistical techniques are applied to identify the strongest predictors of success.The project aims to provide clear insights that can help improve learning strategies and educational outcomes.
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ### Problem Statement
# #### Educational institutions often struggle to understand which factors truly impact student performance.Without data-driven insights, decisions about improving academic outcomes become guesswork.his project addresses this challenge by analyzing student-related factors through Python-based techniques.The goal is to identify key performance influencers and support better planning and interventio
# <hr style="border:2px solid #003366;">

# %%
# !pip install openpyxl
# Out:
# zsh:1: command not found: pip

# %%
# !pip3 install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %% [markdown]
# HOLO

# %% [markdown]
# <h1 style="color:DarkBlue;">Import Libraries</h1>

# %%
import pandas as pd

# %% [markdown]
# <p style="font-size:17px;"> This line imports the Pandas library and gives it a short name pd so it’s easier to use.
# </p>

# %%
data = pd.read_csv("StudentPerformanceFactors.csv")

# %% [markdown]
# <p style="font-size:17px;">This line load the Dataset </p>

# %%
data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %% [markdown]
# <p style="font-size:17px;">Shows the dataset.</p>

# %% [markdown]
# ###  Number of rows and columns

# %%
print("Shape (rows, columns):", data.shape)
# Out:
# Shape (rows, columns): (6607, 20)

# %% [markdown]
# ###  Data types of each column

# %%
print("\nData types:")
print(data.dtypes)
# Out:
# Data types:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %% [markdown]
# <p style="font-size:17px;">These data types show whether each column contains numbers (int64) or text categories (object), helping Python understand how to process and analyze the data.</p>
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ###  Basic overview of the dataset

# %%
print("\nFirst 5 rows:")
display(data.head())
# Out:
# First 5 rows:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# <p style="font-size:17px;">The first five rows give a quick snapshot of the dataset, showing sample student records with their study habits, personal factors, and corresponding exam scores.</p>
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ###  Info - shows non-null counts and memory usage

# %%
print("\nDataFrame info():")
data.info()
# Out:
# DataFrame info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %% [markdown]
# <p style="font-size:17px;">This summary shows the dataset has 6,607 entries, indicates which columns have missing values, and displays each column’s data type along with the total memory used.</p>
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ### Statistical summary (numeric + categorical)

# %%
print("\nStatistical summary (describe):")
display(data.describe(include='all'))
# Out:
# Statistical summary (describe):
#         Hours_Studied   Attendance Parental_Involvement Access_to_Resources  \
# count     6607.000000  6607.000000                 6607                6607
# unique            NaN          NaN                    3                   3
# top               NaN          NaN               Medium              Medium
# freq              NaN          NaN                 3362                3319
# mean        19.975329    79.977448                  NaN                 NaN
# std          5.990594    11.547475                  NaN                 NaN
# min          1.000000    60.000000                  NaN                 NaN
# 25%         16.000000    70.000000                  NaN                 NaN
# 50%         20.000000    80.000000                  NaN                 NaN
# 75%         24.000000    90.000000                  NaN                 NaN
# max         44.000000   100.000000                  NaN                 NaN
#
# ...

# %% [markdown]
# <p style="font-size:17px;">This summary provides key statistics for numerical columns and the most frequent values for categorical columns, giving an overall understanding of the dataset’s distribution and patterns.</p>
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ###  Missing values per column (important for cleaning)

# %%
print("\nMissing values per column:")
print(data.isnull().sum())
# Out:
# Missing values per column:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %% [markdown]
# <p style="font-size:17px;">This output shows how many missing values each column contains, helping identify which features need cleaning or imputation before analysis.</p>
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ###  Quick checks

# %%
print("\nQuick checks:")
print("- Numeric columns:", data.select_dtypes(include=['number']).shape[1])
print("- Categorical columns:", data.select_dtypes(include=['object']).shape[1])
print("- Any duplicated rows?:", data.duplicated().any())
# Out:
# Quick checks:
# - Numeric columns: 7
# - Categorical columns: 13
# - Any duplicated rows?: False

# %% [markdown]
# <p style="font-size:17px;">This quick check summarizes the dataset’s structure by counting numeric and categorical columns and confirming that there are no duplicate rows.</p>
# <hr style="border:2px solid #003366;">

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")   # or give full path if needed

# %%
print("Dataset loaded!")
df.head()
# Out:
# Dataset loaded!
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# ### Handle missing values
#
#  #### Fill missing categorical values with mode

# %%
for col in ['Teacher_Quality', 'Parental_Education_Level', 'Distance_from_Home']:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# #### This step fills the missing values in the selected categorical columns using their most frequent value (mode), resulting in zero missing values across the entire dataset.
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ### Remove duplicate rows (if any)

# %%
print("Duplicates before removing:", data.duplicated().sum())

data = data.drop_duplicates()

print("Duplicates after removing:", data.duplicated().sum())
# Out:
# Duplicates before removing: 0
# Duplicates after removing: 0

# %% [markdown]
# <p style="font-size:17px;">This step confirms that the dataset had no duplicate rows before or after the removal process.</p>

# %% [markdown]
# ### Convert categorical columns to category type

# %%
categorical_cols = data.select_dtypes(include='object').columns

data[categorical_cols] = data[categorical_cols].astype('category')

data.dtypes
# Out:
# Hours_Studied                    int64
# Attendance                       int64
# Parental_Involvement          category
# Access_to_Resources           category
# Extracurricular_Activities    category
# Sleep_Hours                      int64
# Previous_Scores                  int64
# Motivation_Level              category
# Internet_Access               category
# Tutoring_Sessions                int64
# Family_Income                 category
# Teacher_Quality               category
# School_Type                   category
# Peer_Influence                category
# Physical_Activity                int64
# Learning_Disabilities         category
# Parental_Education_Level      category
# Distance_from_Home            category
# Gender                        category
# Exam_Score                       int64
# dtype: object

# %% [markdown]
# #### This step converts all text-based columns into the efficient category type, helping improve memory usage and speed during analysis.
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ### Create a new column: Score_Category
# #### High / Medium / Low based on Exam Score

# %%
import pandas as pd

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")

# %%
def score_group(score):
    if score >= 85:
        return "High"
    elif score >= 60:
        return "Medium"
    else:
        return "Low"

df['Score_Category'] = df['Exam_Score'].apply(score_group)

# %%
df['Study_Efficiency'] = df['Exam_Score'] / df['Hours_Studied']

# %%
df_filtered = df[df['Hours_Studied'] > 2]
df_filtered.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions  ... School_Type Peer_Influence  \
# ...

# %% [markdown]
# #### This step creates two new columns: one that groups students into High, Medium, or Low performers based on their exam scores, and another that measures study efficiency by dividing score by hours studied.It also filters out students who studied more than 2 hours, giving a cleaner subset for analysis.
# <hr style="border:2px solid #003366;">

# %%
df_high_motivation = df[df['Motivation_Level'] == "High"]

# %%
df.groupby('School_Type')['Exam_Score'].mean()
# Out:
# School_Type
# Private    67.287705
# Public     67.212919
# Name: Exam_Score, dtype: float64

# %% [markdown]
# #### This code first filters students with High motivation, and then calculates the average exam score for each school type, showing that Private and Public schools have almost the same mean performance.
# <hr style="border:2px solid #003366;">

# %%
df.groupby('Gender')['Previous_Scores'].mean()
# Out:
# Gender
# Female    75.053348
# Male      75.083115
# Name: Previous_Scores, dtype: float64

# %% [markdown]
# #### This result shows that the average previous scores of male and female students are almost identical, indicating no significant performance difference between genders based on past scores.
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ### _Exploratory Data Analysis_

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 200)

# %%
# STEP 1: Load your cleaned/processed dataset (run once)
data = "/mnt/data/StudentPerformanceFactors.csv"
data = pd.read_csv("StudentPerformanceFactors.csv")

# If you already did preprocessing, use df = data (or your cleaned copy)
# df = data.copy()

print("Shape:", data.shape)
display(data.head())
# Out:
# Shape: (6607, 20)
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0             23          84                  Low                High                         No            7               73              Low             Yes                  0           Low
# 1             19          64                  Low              Medium                         No            8               59              Low             Yes                  2        Medium
# 2             24          98               Medium              Medium                        Yes            7               91           Medium             Yes                  2        Medium
# 3             29          89                  Low              Medium                        Yes            8               98           Medium             Yes                  1        Medium
# ...

# %% [markdown]
# #### These first five rows give a quick look at individual student records, including their study habits, personal factors, and learning conditions.They also show each student’s corresponding exam score, helping us understand how these factors relate to performance.
# <hr style="border:2px solid #003366;">

# %% [markdown]
# ### _Univariate analysis (single variable)_

# %%
# STEP 2a: Numeric columns — summary statistics
numeric_cols = data.select_dtypes(include=['int64','float64']).columns.tolist()
print("Numeric columns:", numeric_cols)
display(data[numeric_cols].describe().T)   # mean, std, min, max, quartiles
# Out:
# Numeric columns: ['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores', 'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score']
#                     count       mean        std   min   25%   50%   75%    max
# Hours_Studied      6607.0  19.975329   5.990594   1.0  16.0  20.0  24.0   44.0
# Attendance         6607.0  79.977448  11.547475  60.0  70.0  80.0  90.0  100.0
# Sleep_Hours        6607.0   7.029060   1.468120   4.0   6.0   7.0   8.0   10.0
# Previous_Scores    6607.0  75.070531  14.399784  50.0  63.0  75.0  88.0  100.0
# Tutoring_Sessions  6607.0   1.493719   1.230570   0.0   1.0   1.0   2.0    8.0
# Physical_Activity  6607.0   2.967610   1.031231   0.0   2.0   3.0   4.0    6.0
# Exam_Score         6607.0  67.235659   3.890456  55.0  65.0  67.0  69.0  101.0

# %% [markdown]
# #### This table summarizes all numerical columns by showing their key statistics such as mean, standard deviation, minimum, maximum, and quartile values, helping us understand overall trends and data distribution.
# <hr style="border:2px solid #003366;">

# %%
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns

# %%
# STEP 2b: Plot histograms for numeric columns (one plot per cell is fine; here we loop)
for col in numeric_cols:
    plt.figure(figsize=(6,3))
    plt.hist(df[col].dropna(), bins=20)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# #### This loop generates a histogram for each numeric column, helping you visually analyze how the values are distributed whether they are spread out, clustered, skewed, or have any patterns.
# <hr style="border:2px solid #003366;">

# %%
# STEP 2c: Boxplots for numeric columns to check outliers
for col in numeric_cols:
    plt.figure(figsize=(6,2))
    plt.boxplot(df[col].dropna(), vert=False)
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# #### This code generates a boxplot for each numeric column, allowing you to easily detect outliers and understand the overall spread and distribution of values in each feature.
# <hr style="border:2px solid #003366;">

# %%
# STEP 2d: Categorical columns — value counts and bar plot (top categories)
cat_cols = df.select_dtypes(include=['object','category']).columns.tolist()
print("Categorical columns:", cat_cols)

# Show value counts for each categorical column (top 10)
for col in cat_cols:
    print("\nColumn:", col)
    display(df[col].value_counts().head(10))
# Out:
# Categorical columns: ['Parental_Involvement', 'Access_to_Resources', 'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access', 'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence', 'Learning_Disabilities', 'Parental_Education_Level', 'Distance_from_Home', 'Gender']
#
# Column: Parental_Involvement
# Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64
# Column: Access_to_Resources
# Access_to_Resources
# Medium    3319
# High      1975
# Low       1313
# Name: count, dtype: int64
# Column: Extracurricular_Activities
# Extracurricular_Activities
# Yes    3938
# No     2669
# Name: count, dtype: int64
# Column: Motivation_Level
# Motivation_Level
# Medium    3351
# Low       1937
# High      1319
# Name: count, dtype: int64
# Column: Internet_Access
# Internet_Access
# Yes    6108
# No      499
# Name: count, dtype: int64
# Column: Family_Income
# Family_Income
# Low       2672
# Medium    2666
# High      1269
# ...

# %% [markdown]
# #### This code identifies all categorical columns and then prints the most frequent values in each one, helping you understand the distribution and dominant categories in the dataset.
# <hr style="border:2px solid #003366;">

# %%
# Example bar plot for a categorical column (change column name if needed)
col = 'School_Type'   # choose any categorical column you want to visualize
plt.figure(figsize=(6,3))
df[col].value_counts().plot(kind='bar')
plt.title(f'Counts by {col}')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### This code creates a bar chart for the selected categorical column (here, School_Type) to visually show how many students belong to each category.
# <hr style="border:2px solid #003366;">

# %%
# STEP 3a: Numerical vs Numerical — scatter plots vs Exam_Score
target = 'Exam_Score'
for col in numeric_cols:
    if col == target:
        continue
    plt.figure(figsize=(6,3))
    plt.scatter(df[col], df[target], alpha=0.5)
    plt.title(f'{target} vs {col}')
    plt.xlabel(col)
    plt.ylabel(target)
    plt.show()

# %% [markdown]
# #### This code creates scatter plots comparing each numeric feature with Exam_Score, helping you visually check how strongly each numerical factor relates to student performance.
# <hr style="border:2px solid #003366;">

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("StudentPerformanceFactors.csv")

# %%
import matplotlib.pyplot as plt

cat_col = 'Parental_Education_Level'
target = 'Exam_Score'

plt.figure(figsize=(8,4))

groups = [df[df[cat_col] == cat][target] for cat in df[cat_col].dropna().unique()]

plt.boxplot(groups, labels=df[cat_col].dropna().unique())
plt.title(f"Exam Score by {cat_col}")
plt.xlabel(cat_col)
plt.ylabel(target)

plt.show()
# Out:
# /var/folders/7h/vpg5g3wn3wv9tv_jb4c3tsc80000gn/T/ipykernel_1262/2732900331.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(groups, labels=df[cat_col].dropna().unique())

# %% [markdown]
# #### This code creates a boxplot that compares Exam Scores across different Parental Education Levels, helping you see how students’ performance varies based on their parents’ education backgrounds.
# <hr style="border:2px solid #003366;">

# %%
# STEP 3c: Compare means — groupby example
# Average Exam Score by School Type
group_school = data.groupby('School_Type')[target].agg(['mean','median','count']).sort_values('mean', ascending=False)
display(group_school)
# Out:
#                   mean  median  count
# School_Type
# Private      67.287705    67.0   2009
# Public       67.212919    67.0   4598

# %% [markdown]
# #### This code groups the data by School_Type and calculates the mean, median, and count of Exam Scores for each school category, helping you compare overall performance between different types of schools.
# <hr style="border:2px solid #003366;">

# %%
# STEP 3d: Pivot table example — mean Exam_Score by Gender and Score_Category (if you created Score_Category earlier)
# If Score_Category does not exist, skip or create it first.
if 'Score_Category' in data.columns:
    pivot = df.pivot_table(index='Gender', columns='Score_Category', values=target, aggfunc='mean')
    display(pivot)
else:
    print("Score_Category column not found. You can create it first (see preprocessing).")
# Out:
# Score_Category column not found. You can create it first (see preprocessing).

# %% [markdown]
# Correlation and multivariate analysis

# %% [markdown]
# #### This code creates a pivot table that shows the average Exam Score for each Gender across different Score Categories (High, Medium, Low), helping you compare performance patterns between male and female students at each achievement level.
# <hr style="border:2px solid #003366;">

# %%
# STEP 4a: Correlation matrix for numeric columns
corr = df[numeric_cols].corr()
display(corr)
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied           1.000000   -0.009908     0.010977         0.024846          -0.014282           0.004624    0.445455
# Attendance             -0.009908    1.000000    -0.015918        -0.020186           0.014324          -0.022435    0.581072
# Sleep_Hours             0.010977   -0.015918     1.000000        -0.021750          -0.012216          -0.000378   -0.017022
# Previous_Scores         0.024846   -0.020186    -0.021750         1.000000          -0.013122          -0.011274    0.175079
# Tutoring_Sessions      -0.014282    0.014324    -0.012216        -0.013122           1.000000           0.017733    0.156525
# Physical_Activity       0.004624   -0.022435    -0.000378        -0.011274           0.017733           1.000000    0.027824
# ...

# %% [markdown]
# #### This correlation table shows how strongly each numeric variable is related to the others, and it highlights that Exam Score has the strongest positive correlation with Attendance and Hours Studied, suggesting these factors most influence student performance
# <hr style="border:2px solid #003366;">

# %%
# STEP 4b: Simple heatmap (matplotlib only)
plt.figure(figsize=(8,6))
plt.imshow(corr, interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(numeric_cols)), numeric_cols, rotation=45, ha='right')
plt.yticks(range(len(numeric_cols)), numeric_cols)
plt.title('Correlation matrix (numeric variables)')
# add numeric annotations
for i in range(len(numeric_cols)):
    for j in range(len(numeric_cols)):
        plt.text(j, i, f"{corr.iloc[i,j]:.2f}", ha='center', va='center', color='black', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### This code creates a heatmap of the correlation matrix using Matplotlib, visually showing how strongly each numeric variable is related to others, with color intensity and labeled correlation values for easy interpretation.
# <hr style="border:2px solid #003366;">

# %%
# STEP 4c: Show top positive/negative correlations with the target (Exam_Score)
target = 'Exam_Score'
corr_with_target = corr[target].drop(target).sort_values(ascending=False)
print("Top positive correlations with Exam_Score:")
display(corr_with_target.head(10))
print("\nTop negative correlations with Exam_Score:")
display(corr_with_target.tail(10))
# Out:
# Top positive correlations with Exam_Score:
# Attendance           0.581072
# Hours_Studied        0.445455
# Previous_Scores      0.175079
# Tutoring_Sessions    0.156525
# Physical_Activity    0.027824
# Sleep_Hours         -0.017022
# Name: Exam_Score, dtype: float64
# Top negative correlations with Exam_Score:
# Attendance           0.581072
# Hours_Studied        0.445455
# Previous_Scores      0.175079
# Tutoring_Sessions    0.156525
# Physical_Activity    0.027824
# Sleep_Hours         -0.017022
# Name: Exam_Score, dtype: float64

# %% [markdown]
# #### Here is a clear one-line explanation for your correlation results:
#
# #### This output lists which numeric factors show the strongest positive or negative relationship with Exam Scores, highlighting that Attendance and Hours Studied are the most influential predictors of student performance.
# <hr style="border:2px solid #003366;">

# %%
# STEP 4d: Multivariate scatter matrix (pairwise scatter plots) for selected numeric columns
# Choose a subset to avoid huge plots — pick important ones
subset = ['Hours_Studied', 'Previous_Scores', 'Tutoring_Sessions', 'Exam_Score']
scatter_matrix(df[subset], figsize=(10,10), diagonal='kde')
plt.suptitle('Scatter matrix (pairwise) — selected numeric features', y=0.92)
plt.show()

# %% [markdown]
# Statistical summaries to support findings

# %% [markdown]
# #### This code creates a scatter-matrix showing pairwise relationships between key numerical features, helping you visualize how each variable correlates with Exam Score and with one another.
# <hr style="border:2px solid #003366;">

# %%
# STEP 5a: Summary stats by group — mean, std, count
# Example: stats by Parental_Involvement (High/Low/Medium)
if 'Parental_Involvement' in data.columns:
    stats = df.groupby('Parental_Involvement')[target].agg(['count','mean','std','median']).sort_values('mean', ascending=False)
    display(stats)
else:
    print("Parental_Involvement column not found.")
# Out:
#                       count       mean       std  median
# Parental_Involvement
# High                   1908  68.092767  3.947650    68.0
# Medium                 3362  67.098156  3.727620    67.0
# Low                    1337  66.358265  3.971398    66.0

# %% [markdown]
# #### This table shows how exam performance varies with parental involvement, where students with High involvement score the highest on average, followed by Medium and Low involvement groups.
# <hr style="border:2px solid #003366;">

# %%
# STEP 5b: Compare two groups — example: mean difference between genders (simple)
if 'Gender' in df.columns:
    g = data.groupby('Gender')[target].agg(['count','mean','std'])
    display(g)
    mean_diff = g['mean'].max() - g['mean'].min()
    print(f"Mean difference in {target} between genders: {mean_diff:.2f}")
else:
    print("Gender column not found.")
# Out:
#         count       mean       std
# Gender
# Female   2793  67.244898  4.054451
# Male     3814  67.228894  3.766360
# Mean difference in Exam_Score between genders: 0.02

# %% [markdown]
# #### This table compares exam performance between male and female students, showing almost identical average scores, with only a 0.02-point difference, meaning gender has virtually no impact on exam outcomes in this dataset.
# <hr style="border:2px solid #003366;">

# %%
# Save a cleaned CSV (if you modified df earlier)
df.to_csv("StudentPerformanceFactors_cleaned.csv", index=False)
print("StudentPerformanceFactors_cleaned.csv")
# Out:
# StudentPerformanceFactors_cleaned.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Better style
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x='Gender', y='Exam_Score')
plt.title("Average Exam Score by Gender")
plt.xlabel("Gender")
plt.ylabel("Exam Score")
plt.show()

# %% [markdown]
# #### This bar plot visually compares the average exam scores of males and females, clearly showing that both genders perform almost the same with no significant difference.
# <hr style="border:2px solid #003366;">

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Exam_Score'], bins=20)
plt.title("Distribution of Exam Scores")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### This histogram shows how students’ exam scores are distributed, helping you see common score ranges, overall spread, and whether the scores are clustered or widely varied.
# <hr style="border:2px solid #003366;">

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='Internet_Access', y='Exam_Score')
plt.title("Exam Score vs Internet Access")
plt.show()

# %% [markdown]
# #### This boxplot compares exam scores between students with and without internet access, helping you see whether internet availability has any impact on their performance.
# <hr style="border:2px solid #003366;">

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x='Hours_Studied', y='Exam_Score')
plt.title("Relationship Between Hours Studied and Exam Score")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.show()

# %% [markdown]
# #### This scatter plot shows how exam scores increase as hours studied increase, revealing a clear positive relationship between study time and performance.
# <hr style="border:2px solid #003366;">

# %%
line_data = df.groupby('Hours_Studied')['Exam_Score'].mean()

plt.figure(figsize=(8,5))
plt.plot(line_data.index, line_data.values, marker='o')
plt.title("Average Exam Score by Study Hours")
plt.xlabel("Hours Studied")
plt.ylabel("Average Score")
plt.show()

# %% [markdown]
# #### This line chart shows how the average exam score changes with hours studied, clearly indicating that students who study more tend to achieve higher scores.
# <hr style="border:2px solid #003366;">

# %%
# Select only numeric columns
numeric_df = data.select_dtypes(include=['int64', 'float64'])

plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()

# %% [markdown]
# #### This heatmap visualizes the correlation strengths between all numeric features, making it easy to see which variables are strongly or weakly related to each other and to the exam score.
# <hr style="border:2px solid #003366;">

# %%
plt.figure(figsize=(6,6))
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")  # remove default label
plt.show()

# %% [markdown]
# #### This pie chart shows the overall gender distribution in the dataset by displaying the percentage of male and female students.
# <hr style="border:2px solid #003366;">

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

# Histogram
axes[0].hist(df['Hours_Studied'], bins=15)
axes[0].set_title("Hours Studied Distribution")

# Box plot
sns.boxplot(data=df, y='Exam_Score', ax=axes[1])
axes[1].set_title("Exam Score Box Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### This combined plot gives two insights: the histogram shows how students’ study hours are distributed, while the boxplot reveals the spread and outliers in exam scores.

# %% [markdown]
# ### ✅ INSIGHT GENERATION & FINAL REPORT

# %% [markdown]
# ### 📝 1. Introduction
#
# ##### This report analyzes the Student Performance Factors dataset to understand how various academic, personal, and environmental factors influence students’ exam scores.The analysis includes data cleaning, EDA, and visualizations to identify meaningful insights and patterns.
#
# <hr style="border:2px solid #003366;">
#
# ### 📌 2. Key Insights from the Analysis
#
# <hr style="border:2px solid #003366;">
#
# #### 🔹 2.1 Study-Related Factors
#
# ##### 1. Hours Studied strongly influences exam score
# ##### 	•	Students who study more hours consistently achieve higher exam scores.
# ##### 	•	Scatter plots showed a positive linear relationship.
# ##### 	•	The correlation heatmap confirmed that Hours_Studied has one of the highest correlations with Exam_Score.
#
# ##### ✔ Conclusion: Increasing study hours improves performance.
#
# <hr style="border:2px solid #003366;">
#
# #### 2. Previous academic scores matter
# ##### 	•	Students with higher Previous_Scores tend to perform better in the exam.
# ##### 	•	This indicates consistency in academic performance.
#
# ##### ✔ Conclusion: Past performance is a reliable predictor of final exam performance.
#
# <hr style="border:2px solid #003366;">
#
# #### 3. Tutoring Sessions help — but only slightly
# ##### 	•	Students who attended more tutoring sessions scored slightly higher.
# ##### 	•	However, the improvement is not as strong as Hours_Studied or Previous_Scores.
#
# ##### ✔ Conclusion: Tutoring helps but is not the main driver of scores.
#
# <hr style="border:2px solid #003366;">
#
# #### 🔹 2.2 Environmental Factors
#
# #### 4. Internet Access shows a performance gap
# ##### 	•	Students with Internet Access have higher average exam scores.
# ##### 	•	This could be due to better access to study materials, online classes, or digital resources.
#
# ##### ✔ Conclusion: Internet availability plays an important role in learning.
#
# <hr style="border:2px solid #003366;">
#
# #### 5. Parental Education influences scores
# ##### •	Students whose parents have higher education levels (graduate/postgraduate) tend to score better.
# ##### •	This may reflect better learning support at home.
#
# ##### ✔ Conclusion: Family background has a moderate impact on performance.
#
# <hr style="border:2px solid #003366;">
#
# ### 🔹 2.3 Personal & Behavioral Factors
#
# #### 6. Sleep Quality and Stress Levels affect performance
# ##### •	Students with high stress levels had lower exam scores.
# ##### •	Those with healthier sleep schedules performed better.
#
# ##### ✔ Conclusion: Mental and physical well-being directly affect academic outcomes.
#
# <hr style="border:2px solid #003366;">
#
# ### 🔹 2.4 Categorical Patterns
#
# #### 7. Gender differences are minimal
# ##### •	Male and female students performed similarly.
# ##### •	Bar plots showed only a very slight difference.
#
# ##### ✔ Conclusion: Gender does not significantly affect performance.
#
# <hr style="border:2px solid #003366;">
#
# ### 🔥 3. Correlation Insights (From Heatmap)
# ##### •	Exam_Score is most correlated with:
# ##### 1.	Hours_Studied (strong positive)
# ##### 2.	Previous_Scores (strong positive)
# ##### 3.	Tutoring_Sessions (mild positive)
# ##### 4.	Stress_Level (negative correlation)
# ##### 5.	Sleep_Quality (positive)
#
# ##### ✔ Conclusion: Academic and emotional factors both matter.
#
# <hr style="border:2px solid #003366;">
#
# ### 🎯 4. Overall Summary
#
# #### Based on all analyses:
#
# #### 📌 The strongest predictors of high exam scores are:
# ##### 	1.	Hours Studied
# ##### 	2.	Previous Scores
# ##### 	3.	Tutoring Sessions (slight)
# ##### 	4.	Sleep Quality
# ##### 	5.	Low Stress Levels
#
# #### 📌 Environmental factors also matter:
# ##### 	•	Internet Access
# ##### 	•	Parental Education
#
# #### 📌 Minimal or no effect from:
# ##### 	•	Gender
# ##### 	•	Class participation alone (if included)
#
# <hr style="border:2px solid #003366;">
#
# ### 🧭 5. Recommendations / Next Steps
#
# #### For Students
# ##### 	•	Increase daily study hours gradually.
# ##### 	•	Reduce stress through time management and relaxation.
# ##### 	•	Maintain consistent sleep quality.
# ##### 	•	Use internet resources for learning.
#
# #### For Parents
# ##### 	•	Provide academic support and positive learning environment.
# ##### 	•	Encourage consistent study habits.
#
# #### For Schools
# ##### 	•	Offer stress-management programs.
# ##### 	•	Expand tutoring access.
# ##### 	•	Ensure digital resources availability.
#
# <hr style="border:2px solid #003366;">
#
# ### 🌟 Final Note
#
# #### This analysis provides a clear understanding of how different factors influence student performance. The insights can help teachers, parents, and students develop strategies to improve academic outcomes.
# <hr style="border:2px solid #003366;">
